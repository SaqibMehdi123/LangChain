# %% [markdown]
# # **using StructuredTool & Pydantic**

# %%
from langchain.tools import StructuredTool
from pydantic import BaseModel, Field
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 11
#       8 class MultiplyOutputs(BaseModel):
#       9     result: int = Field(..., description="The result of the multiplication")
# ---> 11 multiply = StructuredTool.from_function(
#      12     func=lambda a, b: a * b,
#      13     inputs=MultiplyInputs,
#      14     outputs=MultiplyOutputs
#      15 )
#      16 result = multiply.invoke({"a": 6, "b": 8})
#      17 print(result)
#
# File ~/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages/langchain_core/tools/structured.py:242, in StructuredTool.from_function(cls, func, coroutine, name, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, **kwargs)
#     240 if description_ is None:
#     241     msg = "Function must have a docstring if description not provided."
# --> 242     raise ValueError(msg)
#     243 if description is None:
#     244     # Only apply if using the function's docstring
#     245     description_ = textwrap.dedent(description_).strip()
#
# ValueError: Function must have a docstring if description not provided.
