# %% [markdown]
# ## **Web Searching Tool --> DuckDuckGo Search**

# %%
# %pip install -U ddgs
# Out:
# Requirement already satisfied: ddgs in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (9.6.1)
# Requirement already satisfied: click>=8.1.8 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from ddgs) (8.2.1)
# Requirement already satisfied: primp>=0.15.0 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=6.0.0 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Requirement already satisfied: anyio in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.10.0)
# Requirement already satisfied: certifi in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Requirement already satisfied: socksio==1.* in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /home/saqib-mehdi/Desktop/LangChain (Generative AI) - CampusX/venv/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke("Who won PSL 10")

print(results)
# Out:
# May 25, 2025 · PSL Winners List: Check out the latest list of PSL winners from 2016 until 2025, including runners-up, venue, player of series, man of the match, most PSL wins & more only on... May 26, 2025 · Hasan Nawaz was named Player of the Tournament at the Pakistan Super League ( PSL ) Season 10 awards ceremony, which took place following a dramatic final. Nawaz had a standout campaign, scoring 399 runs in 10 matches with an average of 57.00 and an impressive strike rate of 162.19. May 26, 2025 · Lahore Qalandars have etched their name in Pakistan Super League history once again by clinching the PSL X title in the most dramatic fashion imaginable. In a nail-biting final against Islamabad United at Lahore’s Gaddafi Stadium, Qalandars secured a sensational last-ball victory to become champions of PSL 2025. May 25, 2025 · LAHORE: Lahore Qalandars were crowned the champions of the Pakistan Super League (PSL) 10 after defeating Quetta Gladiators by six wickets in the final at Gaddafi Stadium on Sunday. PSL 10 final delivered a rollercoaster of emotions as Lahore Qalandars edged out their opponents in a match packed with breathtaking moments. From thrilling last-ball finishes to electrifying ...

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %%
print(search_tool.args_schema.model_json_schema())
# Out:
# {'description': 'Input for the DuckDuckGo search tool.', 'properties': {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}, 'required': ['query'], 'title': 'DDGInput', 'type': 'object'}
